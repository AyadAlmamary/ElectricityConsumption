# %% [markdown]
# <a href="https://colab.research.google.com/github/AyadAlmamary/ElectricityConsumption/blob/main/ElectricityConsumptionData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Consumption = pd.read_csv('consumptionData.csv')

sns.jointplot( x ='Temperature',y = 'Consumption', data = Consumption , color = 'red')

sns.pairplot(Consumption)

sns.lmplot( x ='Temperature',y = 'Consumption', data = Consumption)

X = Consumption[['Temperature']]
y = Consumption['Consumption']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
from sklearn.linear_model import LinearRegression

regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train, y_train)

print('m_coeff = ',regressor.coef_ )
print('b_coeff = ',regressor.intercept_ )

plt.scatter(X_train, y_train, color= 'blue')
plt.plot(X_train, regressor.predict(X_train), color= 'red')
plt.ylabel('Consumption [Mega Watts]')
plt.xlabel('Temprature [degC]')
plt.title('Electricity Consumption vs. Temp (Training)')
# Out:
# m_coeff =  [21.47750357]
# b_coeff =  43.54928217083136
# Text(0.5, 1.0, 'Electricity Consumption vs. Temp (Training)')

# %%
Temp = 55.0

Predict = regressor.predict(np.array([Temp]).reshape(1, 1))
Predict
# Out:
# array([1224.94152833])

# %%
Temp = 60.0

Predict = regressor.predict(np.array([Temp]).reshape(1, 1))
Predict
# Out:
# array([1332.34244159])

# %%
Temp = 65.0

Predict = regressor.predict(np.array([Temp]).reshape(1, 1))
Predict
# Out:
# array([1439.74335486])
